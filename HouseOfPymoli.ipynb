# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

file_to_load = "purchase_data.csv"
purchase_data_df = pd.read_csv(file_to_load)
purchase_data_df.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# ...

# %%
purchase_data_df.shape
# Out:
# (780, 7)

# %%
# Calculate the Number of Unique Players
player_demographics = purchase_data_df.loc[:, ["Gender", "SN", "Age"]]
player_demographics = player_demographics.drop_duplicates()
num_players = player_demographics.count()[0]

# Display the total number of players
pd.DataFrame({"Total Players": [num_players]})
# Out:
#    Total Players
# 0            576

# %%
unique_items = len(purchase_data_df["Item ID"].unique())
unique_items
# Out:
# 183

# %%
average_price = purchase_data_df["Price"].mean()
average_price
# Out:
# 3.050987179487176

# %%
total_purchases = purchase_data_df["Price"].count()
total_purchases
# Out:
# 780

# %%
revenue = purchase_data_df["Price"].sum()
revenue
# Out:
# 2379.77

# %%
summary_table = pd.DataFrame({"Number of Unique Items": unique_items, "Average Price": [average_price], "Number of Purchases": [total_purchases], "Total Revenue": [revenue]})
summary_table
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     183       3.050987                  780        2379.77

# %%
gender_total = player_demographics["Gender"].value_counts()
gender_total

gender_percentage = gender_total/num_players*100
gender_percentage
# Out:
# Male                     84.027778
# Female                   14.062500
# Other / Non-Disclosed     1.909722
# Name: Gender, dtype: float64

# %%
gender_demographics = pd.DataFrame({"Total Count": gender_total,"Percentage of Players": gender_percentage})
gender_demographics
# Out:
#                        Total Count  Percentage of Players
# Male                           484              84.027778
# Female                          81              14.062500
# Other / Non-Disclosed           11               1.909722

# %%
purchase_count = purchase_data_df["Gender"].value_counts()
purchase_count
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
average_purchase_price = purchase_data_df.groupby('Gender')['Price'].mean()
average_purchase_price
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
total_purchase_value = purchase_data_df.groupby('Gender')['Price'].sum()
total_purchase_value
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
avg_purchase = total_purchase_value/gender_demographics["Total Count"]
avg_purchase
# Out:
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64

# %%
gender_data = pd.DataFrame({"Purchase Count": purchase_count, 
                            "Average Purchase Price": average_purchase_price, 
                            "Total Purchase Value": total_purchase_value, 
                            "Average Total Purchase Per Person": avg_purchase})
gender_data
# Out:
#                        Purchase Count  Average Purchase Price  \
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Average Total Purchase Per Person
# Female                               361.94                           4.468395
# Male                                1967.64                           4.065372
# Other / Non-Disclosed                 50.19                           4.562727

# %%
bins = [0, 9.90, 14.90, 19.90, 24.9, 29.9, 34.90, 39.90, 9999999]

group_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", ">40"]



player_demographics["Age Group"] = pd.cut(player_demographics["Age"], bins, labels=group_labels)
player_demographics.head()
# Out:
#   Gender             SN  Age Age Group
# 0   Male        Lisim78   20     20-24
# 1   Male    Lisovynya38   40       >40
# 2   Male     Ithergue48   24     20-24
# 3   Male  Chamassasya86   24     20-24
# 4   Male      Iskosia90   23     20-24

# %%
age_totals = player_demographics["Age Group"].value_counts()
age_totals
# Out:
# 20-24    258
# 15-19    107
# 25-29     77
# 30-34     52
# 35-39     31
# 10-14     22
# <10       17
# >40       12
# Name: Age Group, dtype: int64

# %%
age_percents = age_totals / num_players * 100
age_percents
# Out:
# 20-24    44.791667
# 15-19    18.576389
# 25-29    13.368056
# 30-34     9.027778
# 35-39     5.381944
# 10-14     3.819444
# <10       2.951389
# >40       2.083333
# Name: Age Group, dtype: float64

# %%
age_demographics = pd.DataFrame({"Total Count": age_totals, "Percent of Players": age_percents})
age_demographics
# Out:
#        Total Count  Percent of Players
# 20-24          258           44.791667
# 15-19          107           18.576389
# 25-29           77           13.368056
# 30-34           52            9.027778
# 35-39           31            5.381944
# 10-14           22            3.819444
# <10             17            2.951389
# >40             12            2.083333

# %%
bins = [0, 9.90, 14.90, 19.90, 24.9, 29.9, 34.90, 39.90, 9999999]

group_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", ">40"]

purchase_data_df["Age Group"] = pd.cut(purchase_data_df["Age"], bins, labels=group_labels)
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       >40
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
Age_Group = purchase_data_df.groupby("Age Group")
Age_Group

# %%
purchase_count = Age_Group["Price"].count() 
purchase_count
# Out:
# Age Group
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# >40       13
# Name: Price, dtype: int64

# %%
avgerage_price = Age_Group["Price"].mean()
average_price
# Out:
# 3.050987179487176

# %%
total_value = Age_Group["Price"].sum()
total_value
# Out:
# Age Group
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# >40        38.24
# Name: Price, dtype: float64

# %%
price_std = Age_Group["Price"].std()
price_std
# Out:
# Age Group
# <10      1.072811
# 10-14    1.095747
# 15-19    1.179904
# 20-24    1.181192
# 25-29    1.158884
# 30-34    1.158957
# 35-39    1.029181
# >40      1.301921
# Name: Price, dtype: float64

# %%
avg_total_ppp = avgerage_price/price_std *100
avg_total_ppp
# Out:
# Age Group
# <10      312.587945
# 10-14    269.809487
# 15-19    257.305289
# 20-24    258.401509
# 25-29    250.326288
# 30-34    252.943436
# 35-39    349.958428
# >40      225.938379
# Name: Price, dtype: float64

# %%
purchase_analysis = pd.DataFrame({"Purcahse Count": purchase_count, "Average Purchase Price": average_price, "Total Purchase Value": total_value, "Average Total Purchase Per Person": avg_total_ppp})
purchase_analysis
# Out:
#            Purcahse Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                    23                3.050987                 77.13
# 10-14                  28                3.050987                 82.78
# 15-19                 136                3.050987                412.89
# 20-24                 365                3.050987               1114.06
# 25-29                 101                3.050987                293.00
# 30-34                  73                3.050987                214.00
# 35-39                  41                3.050987                147.67
# >40                    13                3.050987                 38.24
#
#            Average Total Purchase Per Person
# Age Group
# <10                               312.587945
# 10-14                             269.809487
# 15-19                             257.305289
# 20-24                             258.401509
# 25-29                             250.326288
# ...

# %%
sn_group = purchase_data_df.groupby("SN")
sn_group

# %%
total_purchase_value = purchase_data_df.groupby(["SN"]).sum()["Price"]

# %%
average_purchase_price = purchase_data_df.groupby(["SN"]).mean()["Price"]

# %%
purchase_count = purchase_data_df.groupby(["SN"]).count()["Price"]

# %%
sn_group = pd.DataFrame(OrderedDict({"Purchase Count":purchase_count.astype(int),
                                        "Average Purchase Price":average_purchase_price.astype(float),
                                        "Total Purchase Value":total_purchase_value.astype(float)}))

sn_group
# Out:
#                  Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76                  1                2.280000                  2.28
# Adastirin33                   1                4.480000                  4.48
# Aeda94                        1                4.910000                  4.91
# Aela59                        1                4.320000                  4.32
# Aelaria33                     1                1.790000                  1.79
# Aelastirin39                  2                3.645000                  7.29
# Aelidru27                     1                1.090000                  1.09
# Aelin32                       3                2.993333                  8.98
# Aelly27                       2                3.395000                  6.79
# Aellynun67                    1                3.740000                  3.74
# Aellyria80                    1                3.080000                  3.08
# ...

# %%
top_spenders = sn_group.sort_values(["Purchase Count"], ascending=False)
top_spenders.head(5)
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Iral74                    4                3.405000                 13.62
# Idastidru52               4                3.862500                 15.45
# Asur53                    3                2.480000                  7.44
# Inguron55                 3                3.703333                 11.11

# %%
pop_items = purchase_data_df.groupby(["Item ID","Item Name"])
pop_items

# %%
purch_count = pop_items["Item ID"].count()
purch_count
# Out:
# Item ID  Item Name
# 0        Splinter                                         4
# 1        Crucifer                                         3
# 2        Verdict                                          6
# 3        Phantomlight                                     6
# 4        Bloodlord's Fetish                               5
# 5        Putrid Fan                                       4
# 6        Rusty Skull                                      2
# 7        Thorn, Satchel of Dark Souls                     7
# 8        Purgatory, Gem of Regret                         3
# 9        Thorn, Conqueror of the Corrupted                4
# 10       Sleepwalker                                      4
# 11       Brimstone                                        5
# 12       Dawne                                            6
# 13       Serenity                                         4
# 14       Possessed Core                                   2
# ...

# %%
item_price = pop_items["Price"].mean()
item_price
# Out:
# Item ID  Item Name
# 0        Splinter                                        1.28
# 1        Crucifer                                        3.26
# 2        Verdict                                         2.48
# 3        Phantomlight                                    2.49
# 4        Bloodlord's Fetish                              1.70
# 5        Putrid Fan                                      4.08
# 6        Rusty Skull                                     3.70
# 7        Thorn, Satchel of Dark Souls                    1.33
# 8        Purgatory, Gem of Regret                        3.93
# 9        Thorn, Conqueror of the Corrupted               2.73
# 10       Sleepwalker                                     1.79
# 11       Brimstone                                       3.65
# 12       Dawne                                           1.02
# 13       Serenity                                        1.41
# 14       Possessed Core                                  2.61
# ...

# %%
total_purchase_value = pop_items["Price"].sum()
total_purchase_value
# Out:
# Item ID  Item Name
# 0        Splinter                                         5.12
# 1        Crucifer                                         9.78
# 2        Verdict                                         14.88
# 3        Phantomlight                                    14.94
# 4        Bloodlord's Fetish                               8.50
# 5        Putrid Fan                                      16.32
# 6        Rusty Skull                                      7.40
# 7        Thorn, Satchel of Dark Souls                     9.31
# 8        Purgatory, Gem of Regret                        11.79
# 9        Thorn, Conqueror of the Corrupted               10.92
# 10       Sleepwalker                                      7.16
# 11       Brimstone                                       18.25
# 12       Dawne                                            6.12
# 13       Serenity                                         5.64
# 14       Possessed Core                                   5.22
# ...

# %%
pop_items = pd.DataFrame(OrderedDict({"Purchase Count":purch_count.astype(int),
                                        "Average Purchase Price":item_price.astype(float),
                                        "Total Purchase Value":total_purchase_value.astype(float)}))

pop_items
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   3
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# 5       Putrid Fan                                                 4
# 6       Rusty Skull                                                2
# 7       Thorn, Satchel of Dark Souls                               7
# 8       Purgatory, Gem of Regret                                   3
# 9       Thorn, Conqueror of the Corrupted                          4
# 10      Sleepwalker                                                4
# 11      Brimstone                                                  5
# ...

# %%
pop_items = pop_items.sort_values(["Purchase Count"], ascending=False)
pop_items.head(5)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Average Purchase Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                    4.23
# 145     Fiery Glass Crusader                                            4.58
# 108     Extraction, Quickblade Of Trembling Hands                       3.53
# 82      Nirvana                                                         4.90
# 19      Pursuit, Cudgel of Necromancy                                   1.02
#
# ...

# %%
top_item = pop_items.sort_values(["Total Purchase Value"], ascending=0)
top_item.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Average Purchase Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                    4.23
# 82      Nirvana                                                         4.90
# 145     Fiery Glass Crusader                                            4.58
# 92      Final Critic                                                    4.88
# 103     Singed Scalpel                                                  4.35
#
# ...
